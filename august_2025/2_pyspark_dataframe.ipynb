# %% [markdown]
# # Dataframe code using AI

# %% [markdown]
# ## sub heading

# %%
data = [
    (1, "A", 10.5, True, "2025-10-06", 100, "foo", 3.14, "bar", None),
    (2, "B", 20.5, False, "2025-10-07", 200, "baz", 2.71, "qux", "extra"),
    (3, "C", 30.5, True, "2025-10-08", 300, "quux", 1.61, "corge", "data"),
    (4, "D", 40.5, False, "2025-10-09", 400, "grault", 0.57, "garply", "test"),
    (5, "E", 50.5, True, "2025-10-10", 500, "waldo", 1.41, "fred", "sample")
]
columns = ["id", "letter", "value", "flag", "date", "score", "str1", "num", "str2", "misc"]
df = spark.createDataFrame(data, columns)
display(df)

# %% [markdown]
# #dataframe using list value

# %%
data_list = [
    (101, "X", 9.99),
    (102, "Y", 19.99),
    (103, "Z", 29.99)
]
columns_list = ["item_id", "item_code", "price"]
df_list = spark.createDataFrame(data_list, columns_list)
display(df_list)
